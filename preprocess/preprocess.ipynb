# %%
import pandas as pd
import numpy as np
import yfinance as yf
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

from google.colab import drive
drive.mount('/content/gdrive')

path = '/content/gdrive/MyDrive/Colab_Notebooks/'
# Out:
# Mounted at /content/gdrive

# %%
full_training_data = pd.read_csv(path+'data/full_training_data.csv',index_col=False)

# %%
full_training_data.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2019-12-02  26475.339844  26511.550781  26393.089844  26444.720703
# 1  2019-12-03  26315.970703  26424.119141  26063.019531  26391.300781
# 2  2019-12-04  26071.390625  26191.789062  25995.150391  26062.560547
# 3  2019-12-05  26300.509766  26300.509766  26134.060547  26217.039062
# 4  2019-12-06  26345.199219  26520.080078  26309.339844  26498.369141
#
#       Adj Close      Volume  created_at  wsentiments  HSI_overnight_ret  \
# 0  26444.720703  1348911800  2019-12-02    -0.792352           0.004891
# 1  26391.300781  1795451800  2019-12-03    -0.954181          -0.004869
# 2  26062.560547  1502327900  2019-12-04    -0.987235          -0.012122
# 3  26217.039062  1228026600  2019-12-05    -0.936432           0.009130
# 4  26498.369141  1644211100  2019-12-06    -0.632721           0.004888
#
#    HSI_intraday_overnight_ret_diff  CSI300_overnight_ret  SSE50_overnight_ret  \
# ...

# %%
full_training_data['wsentiments'] = full_training_data['wsentiments'].interpolate()

# %%
full_training_data['wsentiments'][77]
# Out:
# -0.36528153717517853

# %%
full_training_data.to_csv(path+'data/full_training_data_cleaned.csv', index=False)
